# %% [markdown]
# # Plot Evolution of Jimmy Butler Career Stats

# %% [markdown]
# ## Imports

# %%
import pandas as pd 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.patheffects as path_effects
import matplotlib.image as mpimg

from PIL import Image

import datetime
from highlight_text import fig_text

# %% [markdown]
# ## Retrieve data

# %%
df = pd.read_csv("../data/career_stats.csv")

# %%
df
# Out:
#      Season  Age   Tm   G  GS    FG%    3P%    2P%   eFG%   FT  ...    FT%  \
# 0   2011-12   22  CHI  42   0  0.405  0.182  0.441  0.418  1.0  ...  0.768
# 1   2012-13   23  CHI  82  20  0.467  0.381  0.489  0.506  2.3  ...  0.803
# 2   2013-14   24  CHI  67  67  0.397  0.283  0.457  0.446  3.9  ...  0.769
# 3   2014-15   25  CHI  65  65  0.462  0.378  0.484  0.502  5.9  ...  0.834
# 4   2015-16   26  CHI  67  67  0.454  0.312  0.489  0.485  5.9  ...  0.832
# 5   2016-17   27  CHI  76  75  0.455  0.367  0.477  0.492  7.7  ...  0.865
# 6   2017-18   28  MIN  59  59  0.474  0.350  0.509  0.512  6.2  ...  0.854
# 7   2018-19   29  TOT  65  65  0.462  0.347  0.494  0.499  4.8  ...  0.855
# 8   2019-20   30  MIA  58  58  0.455  0.244  0.495  0.474  7.6  ...  0.834
# 9   2020-21   31  MIA  52  52  0.497  0.245  0.538  0.514  6.9  ...  0.863
# 10  2021-22   32  MIA  23  23  0.500  0.250  0.535  0.515  7.0  ...  0.871
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'G', 'GS', 'FG%', '3P%', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS'],
#       dtype='object')

# %% [markdown]
# ## Plot the classic stats

# %%
fig,ax = plt.subplots(figsize = (11,7))

#Add grid to the plot
ax.grid(ls="dotted", lw="0.5", color="w", zorder=1)

hfont = {'fontname':'Impact'}

#Change the background color
fig.set_facecolor("#08143D")
ax.patch.set_facecolor("#08143D")

#Change the ticks color
ax.tick_params(colors="w", length=15)

#Change the axes color
ax.spines['bottom'].set_color("w")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color("w")

# Plot the differents stats
plt.plot(df['Season'], df['PTS'], zorder=0, color="#2bb6e0", label = "Points/G")
plt.plot(df['Season'], df['AST'], zorder=0, color="#8BF600", label = "Assists/G")
plt.plot(df['Season'], df['TRB'], zorder=0, color="#D200A4", label = "Rebounds/G")
#plt.plot(df['Season'], df['FT'], zorder=0, color="#03D9E3", label = "FT/G")

# Set the ticks
#plt.xticks(['2008-01', '2010-01','2013-12','2016-01','2017-12','2020-04'])
plt.yticks([0,10,20,30])
ax.set_ylim(0,30)
plt.xlim(xmin='2011-12')

# Axes Label
plt.xlabel("Season", color="w", fontsize=15 , **hfont)
plt.ylabel("Stats perGame", color="w", fontsize=15 , **hfont)

# Title and credits
fig_text(0.12,0.97, s="Evolution of <Jimmy Butler> statistics since his debut in NBA\n", highlight_textprops=[{"color": '#2bb6e0'}], fontsize = 16, fontweight = "bold", color = "w", **hfont)
fig.text(0.12,0.9, "From Most Improved Player to All-Star player to Franchise Player, Butler forged his way to the top of the NBA", fontsize = 12, fontweight="light", color = "w", **hfont)
fig.text(0.05, 0, "Created by Jacky KUOCH / Data from Basketball Reference",fontstyle="italic",fontsize=9, color="w")


# Split the graph in four parts for each team he played for
ax.axvline(x='2017-18', color="w", linestyle = '--', alpha = 0.5, zorder =3)
ax.axvline(x='2018-19', color="w", linestyle = '--', alpha = 0.5, zorder =3)
ax.axvline(x='2019-20', color="w", linestyle = '--', alpha = 0.5, zorder =3)

## Chicago Bulls
ax.text('2014-15', 26, "Chicago\nBulls", fontsize=15, ha="center", color="w",alpha = 0.7, zorder =2, **hfont)
## Minnesota Timberwolves
ax.text(6.5, 26, "Minnesota\nTimberwolves", fontsize=15, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)
## Philadelphia Sixers
ax.text(7.8, 26, "Philadelphia\nSixers", fontsize=15, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)
## Miami Heat
ax.text(9.5, 26, "Miami\nHeat", fontsize=15, ha="center", color="w",alpha = 0.7,zorder =2, **hfont)

# Add points on key dates

## Highest Average Points
ax.scatter(x='2016-17',y=23.9, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
ptsmax = ax.text(x='2016-17', y=25, s="23.9 PTS", fontsize=13, ha="center", color="#2bb6e0", **hfont)
ptsmax.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## Highest Average Assists
ax.scatter(x='2020-21',y=7.1, s=120, color="#8BF600", edgecolors="w", lw=1, zorder=3 )
astmax = ax.text(x='2020-21', y=7.8, s="7.1 AST", fontsize=13, ha="center", color="#8BF600", **hfont)
astmax.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## First All-Star Game
ax.scatter(x='2014-15',y=20, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
asg = ax.text(x='2014-15', y=20.8, s="First All-Star\nGame", fontsize=13, ha="center", color="#2bb6e0", **hfont)
asg.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## Became Starter
ax.scatter(x='2013-14',y=13.1, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
starter = ax.text(x='2013-14', y=13.6, s="Bulls\nStarter", fontsize=13, ha="center", color="#2bb6e0", **hfont)
starter.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## NBA Finals
ax.scatter(x=8.7,y=21, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
finals = ax.text(x=8.7, y=21.8, s="NBA\nFinals", fontsize=13, ha="center", color="#2bb6e0", **hfont)
finals.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])


plt.legend(loc='upper left')

plt.show()
plt.tight_layout()

# %%
df.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'G', 'GS', 'FG%', '3P%', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize = (11,7))

#Add grid to the plot
ax.grid(ls="dotted", lw="0.5", color="w", zorder=1)

hfont = {'fontname':'Impact'}

#Change the background color
fig.set_facecolor("#08143D")
ax.patch.set_facecolor("#08143D")

#Change the ticks color
ax.tick_params(colors="w", length=15)

#Change the axes color
ax.spines['bottom'].set_color("w")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color("w")

# Plot the differents stats
plt.plot(df['Season'], df['FT%'], zorder=0, color="#2bb6e0", label = "%FG")
plt.plot(df['Season'], df['3P%'], zorder=0, color="#8BF600", label = "%3P")
plt.plot(df['Season'], df['FG%'], zorder=0, color="#D200A4", label = "%FT")
#plt.plot(df['Season'], df['FT'], zorder=0, color="#03D9E3", label = "FT/G")

# Set the ticks
#plt.xticks(['2008-01', '2010-01','2013-12','2016-01','2017-12','2020-04'])
plt.yticks([0,0.25,0.5,0.75, 1])
ax.set_ylim(0,1.2)
plt.xlim(xmin='2011-12')

# Axes Label
plt.xlabel("Season", color="w", fontsize=15 , **hfont)
plt.ylabel("Percentage", color="w", fontsize=15 , **hfont)

# Title and credits
fig_text(0.12,0.97, s="Evolution of <Jimmy Butler> statistics since his debut in NBA\n", highlight_textprops=[{"color": '#2bb6e0'}], fontsize = 16, fontweight = "bold", color = "w", **hfont)
fig.text(0.12,0.9, "From Most Improved Player to All-Star player to Franchise Player, Butler forged his way to the top of the NBA", fontsize = 12, fontweight="light", color = "w", **hfont)
fig.text(0.05, 0, "Created by Jacky KUOCH / Data from Basketball Reference",fontstyle="italic",fontsize=9, color="w")


# Split the graph in four parts for each team he played for
ax.axvline(x='2017-18', color="w", linestyle = '--', alpha = 0.5, zorder =3)
ax.axvline(x='2018-19', color="w", linestyle = '--', alpha = 0.5, zorder =3)
ax.axvline(x='2019-20', color="w", linestyle = '--', alpha = 0.5, zorder =3)

## Chicago Bulls
ax.text('2014-15', 1.1, "Chicago\nBulls", fontsize=15, ha="center", color="w",alpha = 0.7, zorder =2, **hfont)
## Minnesota Timberwolves
ax.text(6.5, 1.1, "Minnesota\nTimberwolves", fontsize=15, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)
## Philadelphia Sixers
ax.text(7.8, 1.1, "Philadelphia\nSixers", fontsize=15, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)
## Miami Heat
ax.text(9.5, 1.1, "Miami\nHeat", fontsize=15, ha="center", color="w",alpha = 0.7,zorder =2, **hfont)

# Add points on key dates



plt.legend(loc='upper left')

plt.show()
plt.tight_layout()

# %%
fig,axs = plt.subplots(1,2,figsize = (19,7))

#Add grid to the plots
axs[0].grid(ls="dotted", lw="0.5", color="w", zorder=1)
axs[1].grid(ls="dotted", lw="0.5", color="w", zorder=1)

hfont = {'fontname':'Impact'}

#Change the background color
fig.set_facecolor("#08143D")
axs[0].patch.set_facecolor("#08143D")
axs[1].patch.set_facecolor("#08143D")

#Change the ticks color
axs[0].tick_params(colors="w", length=15)
axs[1].tick_params(colors="w", length=15)

#Change the axes color
## First plot
axs[0].spines['bottom'].set_color("w")
axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)
axs[0].spines['left'].set_color("w")

## Second plot
axs[1].spines['bottom'].set_color("w")
axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
axs[1].spines['left'].set_color("w")

# Plot the differents stats
## First plot
axs[0].plot(df['Season'], df['PTS'], zorder=0, color="#2bb6e0", label = "Points/G")
axs[0].plot(df['Season'], df['AST'], zorder=0, color="#8BF600", label = "Assists/G")
axs[0].plot(df['Season'], df['TRB'], zorder=0, color="#D200A4", label = "Rebounds/G")

## Second plot
axs[1].plot(df['Season'], df['FT%'], zorder=0, color="#2bb6e0", label = "%FT")
axs[1].plot(df['Season'], df['3P%'], zorder=0, color="#8BF600", label = "%3P")
axs[1].plot(df['Season'], df['FG%'], zorder=0, color="#D200A4", label = "%FG")

# Set the ticks and xlim
plt.sca(axs[0])
plt.yticks([0,5,10,15,20,25,30])
plt.xlim(xmin='2011-12')

plt.sca(axs[1])
plt.yticks([0,0.25,0.5,0.75, 1])
plt.xlim(xmin='2011-12')

## Set ylimits
axs[0].set_ylim(0,30)
axs[1].set_ylim(0,1)

# Axes Label
## First plot
axs[0].set_xlabel("Season", color="w", fontsize=15 , **hfont)
axs[0].set_ylabel("Stats perGame", color="w", fontsize=15 , **hfont)

## Second plot
axs[1].set_xlabel("Season", color="w", fontsize=15 , **hfont)
axs[1].set_ylabel("Shooting Percentage", color="w", fontsize=15 , **hfont)

# Title and credits
fig_text(0.12,0.97, s="Evolution of <Jimmy Butler> statistics since his debut in NBA\n", highlight_textprops=[{"color": '#2bb6e0'}], fontsize = 16, fontweight = "bold", color = "w", **hfont)
fig.text(0.12,0.9, "From Most Improved Player to All-Star player to Franchise Player, Butler forged his way to the top of the NBA.", fontsize = 12, fontweight="light", color = "w", **hfont)
fig.text(0.1, -0.025, "Created by Jacky KUOCH / Data from Basketball Reference",fontstyle="italic",fontsize=11, color="w")


# Split the graph in four parts for each team he played for
axs[0].axvline(x='2017-18', color="w", linestyle = '--', alpha = 0.5, zorder =3)
axs[0].axvline(x='2018-19', color="w", linestyle = '--', alpha = 0.5, zorder =3)
axs[0].axvline(x='2019-20', color="w", linestyle = '--', alpha = 0.5, zorder =3)

axs[1].axvline(x='2017-18', color="w", linestyle = '--', alpha = 0.5, zorder =3)
axs[1].axvline(x='2018-19', color="w", linestyle = '--', alpha = 0.5, zorder =3)
axs[1].axvline(x='2019-20', color="w", linestyle = '--', alpha = 0.5, zorder =3)

## Chicago Bulls
axs[0].text('2014-15', 26, "Chicago\nBulls", fontsize=12, ha="center", color="w",alpha = 0.7, zorder =2, **hfont)
axs[1].text('2014-15', 0.9, "Chicago\nBulls", fontsize=12, ha="center", color="w",alpha = 0.7, zorder =2, **hfont)

## Minnesota Timberwolves
axs[0].text(6.5, 26, "Minnesota\nTimberwolves", fontsize=12, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)
axs[1].text(6.5, 0.9, "Minnesota\nTimberwolves", fontsize=12, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)

## Philadelphia Sixers
axs[0].text(7.9, 26, "Philadelphia\nSixers", fontsize=12, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)
axs[1].text(7.8, 0.9, "Philadelphia\nSixers", fontsize=12, ha="center", color="w",alpha = 0.7 ,zorder =2, **hfont)

## Miami Heat
axs[0].text(9.9, 26, "Miami\nHeat", fontsize=12, ha="center", color="w",alpha = 0.7,zorder =2, **hfont)
axs[1].text(9.3, 0.9, "Miami\nHeat", fontsize=12, ha="center", color="w",alpha = 0.7,zorder =2, **hfont)


# Add points on key dates

## Highest Average Points
axs[0].scatter(x='2016-17',y=23.9, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
ptsmax = axs[0].text(x='2016-17', y=25, s="23.9 PTS", fontsize=13, ha="center", color="#2bb6e0", **hfont)
ptsmax.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## Highest Average Assists
axs[0].scatter(x='2020-21',y=7.1, s=120, color="#8BF600", edgecolors="w", lw=1, zorder=3 )
astmax = axs[0].text(x='2020-21', y=7.8, s="7.1 AST", fontsize=13, ha="center", color="#8BF600", **hfont)
astmax.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## First All-Star Game
axs[0].scatter(x='2014-15',y=20, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
asg = axs[0].text(x='2014-15', y=20.8, s="First All-Star\nGame", fontsize=13, ha="center", color="#2bb6e0", **hfont)
asg.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## Became Starter
axs[0].scatter(x='2013-14',y=13.1, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
starter = axs[0].text(x='2013-14', y=13.6, s="Bulls\nStarter", fontsize=13, ha="center", color="#2bb6e0", **hfont)
starter.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## NBA Finals
axs[0].scatter(x=8.7,y=21, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
finals = axs[0].text(x=8.7, y=21.8, s="NBA\nFinals", fontsize=13, ha="center", color="#2bb6e0", **hfont)
finals.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## Highest FT Percentage
axs[1].scatter(x='2021-22',y=0.87, s=120, color="#2bb6e0", edgecolors="w", lw=1, zorder=3 )
ftmax = axs[1].text(x='2021-22', y=0.89, s="87%", fontsize=13, ha="center", color="#2bb6e0", **hfont)
ftmax.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## Highest FGPercentage
axs[1].scatter(x='2021-22',y=0.5, s=120, color="#D200A4", edgecolors="w", lw=1, zorder=3 )
fgmax = axs[1].text(x='2021-22', y=0.52, s="50%", fontsize=13, ha="center", color="#D200A4", **hfont)
fgmax.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])

## Highest 3PTPercentage
axs[1].scatter(x='2012-13',y=0.381, s=120, color="#8BF600", edgecolors="w", lw=1, zorder=3 )
fgmax = axs[1].text(x='2012-13', y=0.4, s="38%", fontsize=13, ha="center", color="#8BF600", **hfont)
fgmax.set_path_effects([path_effects.withStroke(linewidth=3, foreground="w")])


#Add legend
axs[0].legend(loc='upper left')
axs[1].legend(loc='upper left')

#fig.tight_layout()
plt.savefig("../assets/butler_career_stats.jpg", dpi=1200, bbox_inches='tight')
plt.show()
